# %%
import pandas as pd

# %%
df = pd.read_csv('../Sesion2/data/sales_data_sample.csv', encoding='ISO-8859-1')

df.head()
# Out:
#    ORDERNUMBER  QUANTITYORDERED  PRICEEACH  ORDERLINENUMBER    SALES  \
# 0        10107               30      95.70                2  2871.00
# 1        10121               34      81.35                5  2765.90
# 2        10134               41      94.74                2  3884.34
# 3        10145               45      83.26                6  3746.70
# 4        10159               49     100.00               14  5205.27
#
#          ORDERDATE   STATUS  QTR_ID  MONTH_ID  YEAR_ID  ...  \
# 0   2/24/2003 0:00  Shipped       1         2     2003  ...
# 1    5/7/2003 0:00  Shipped       2         5     2003  ...
# 2    7/1/2003 0:00  Shipped       3         7     2003  ...
# 3   8/25/2003 0:00  Shipped       3         8     2003  ...
# 4  10/10/2003 0:00  Shipped       4        10     2003  ...
#
#                     ADDRESSLINE1  ADDRESSLINE2           CITY STATE  \
# 0        897 Long Airport Avenue           NaN            NYC    NY
# ...

# %%
df.tail()
# Out:
#       ORDERNUMBER  QUANTITYORDERED  PRICEEACH  ORDERLINENUMBER    SALES  \
# 2818        10350               20     100.00               15  2244.40
# 2819        10373               29     100.00                1  3978.51
# 2820        10386               43     100.00                4  5417.57
# 2821        10397               34      62.24                1  2116.16
# 2822        10414               47      65.52                9  3079.44
#
#            ORDERDATE    STATUS  QTR_ID  MONTH_ID  YEAR_ID  ...  \
# 2818  12/2/2004 0:00   Shipped       4        12     2004  ...
# 2819  1/31/2005 0:00   Shipped       1         1     2005  ...
# 2820   3/1/2005 0:00  Resolved       1         3     2005  ...
# 2821  3/28/2005 0:00   Shipped       1         3     2005  ...
# 2822   5/6/2005 0:00   On Hold       2         5     2005  ...
#
#                ADDRESSLINE1  ADDRESSLINE2      CITY STATE POSTALCODE  COUNTRY  \
# ...

# %%
df.columns
# Out:
# Index(['ORDERNUMBER', 'QUANTITYORDERED', 'PRICEEACH', 'ORDERLINENUMBER',
#        'SALES', 'ORDERDATE', 'STATUS', 'QTR_ID', 'MONTH_ID', 'YEAR_ID',
#        'PRODUCTLINE', 'MSRP', 'PRODUCTCODE', 'CUSTOMERNAME', 'PHONE',
#        'ADDRESSLINE1', 'ADDRESSLINE2', 'CITY', 'STATE', 'POSTALCODE',
#        'COUNTRY', 'TERRITORY', 'CONTACTLASTNAME', 'CONTACTFIRSTNAME',
#        'DEALSIZE'],
#       dtype='object')

# %%
df.describe()
# Out:
#         ORDERNUMBER  QUANTITYORDERED    PRICEEACH  ORDERLINENUMBER  \
# count   2823.000000      2823.000000  2823.000000      2823.000000
# mean   10258.725115        35.092809    83.658544         6.466171
# std       92.085478         9.741443    20.174277         4.225841
# min    10100.000000         6.000000    26.880000         1.000000
# 25%    10180.000000        27.000000    68.860000         3.000000
# 50%    10262.000000        35.000000    95.700000         6.000000
# 75%    10333.500000        43.000000   100.000000         9.000000
# max    10425.000000        97.000000   100.000000        18.000000
#
#               SALES       QTR_ID     MONTH_ID     YEAR_ID         MSRP
# count   2823.000000  2823.000000  2823.000000  2823.00000  2823.000000
# mean    3553.889072     2.717676     7.092455  2003.81509   100.715551
# std     1841.865106     1.203878     3.656633     0.69967    40.187912
# min      482.130000     1.000000     1.000000  2003.00000    33.000000
# ...

# %%
df.dtypes
# Out:
# ORDERNUMBER           int64
# QUANTITYORDERED       int64
# PRICEEACH           float64
# ORDERLINENUMBER       int64
# SALES               float64
# ORDERDATE            object
# STATUS               object
# QTR_ID                int64
# MONTH_ID              int64
# YEAR_ID               int64
# PRODUCTLINE          object
# MSRP                  int64
# PRODUCTCODE          object
# CUSTOMERNAME         object
# PHONE                object
# ADDRESSLINE1         object
# ADDRESSLINE2         object
# CITY                 object
# STATE                object
# POSTALCODE           object
# COUNTRY              object
# TERRITORY            object
# CONTACTLASTNAME      object
# CONTACTFIRSTNAME     object
# DEALSIZE             object
# dtype: object

# %%
df.isnull().sum().sort_values(ascending = False)
# Out:
# ADDRESSLINE2        2521
# STATE               1486
# TERRITORY           1074
# POSTALCODE            76
# SALES                  0
# QUANTITYORDERED        0
# PRICEEACH              0
# ORDERLINENUMBER        0
# ORDERNUMBER            0
# MONTH_ID               0
# QTR_ID                 0
# STATUS                 0
# ORDERDATE              0
# PRODUCTCODE            0
# YEAR_ID                0
# MSRP                   0
# PRODUCTLINE            0
# ADDRESSLINE1           0
# PHONE                  0
# CUSTOMERNAME           0
# CITY                   0
# COUNTRY                0
# CONTACTLASTNAME        0
# CONTACTFIRSTNAME       0
# DEALSIZE               0
# dtype: int64

# %%
df.isnull().sum() / df.isnull().count()
# Out:
# ORDERNUMBER         0.000000
# QUANTITYORDERED     0.000000
# PRICEEACH           0.000000
# ORDERLINENUMBER     0.000000
# SALES               0.000000
# ORDERDATE           0.000000
# STATUS              0.000000
# QTR_ID              0.000000
# MONTH_ID            0.000000
# YEAR_ID             0.000000
# PRODUCTLINE         0.000000
# MSRP                0.000000
# PRODUCTCODE         0.000000
# CUSTOMERNAME        0.000000
# PHONE               0.000000
# ADDRESSLINE1        0.000000
# ADDRESSLINE2        0.893022
# CITY                0.000000
# STATE               0.526390
# POSTALCODE          0.026922
# COUNTRY             0.000000
# TERRITORY           0.380446
# CONTACTLASTNAME     0.000000
# CONTACTFIRSTNAME    0.000000
# DEALSIZE            0.000000
# dtype: float64

# %%
df.select_dtypes(include=['object'])
# Out:
#             ORDERDATE    STATUS  PRODUCTLINE PRODUCTCODE  \
# 0      2/24/2003 0:00   Shipped  Motorcycles    S10_1678
# 1       5/7/2003 0:00   Shipped  Motorcycles    S10_1678
# 2       7/1/2003 0:00   Shipped  Motorcycles    S10_1678
# 3      8/25/2003 0:00   Shipped  Motorcycles    S10_1678
# 4     10/10/2003 0:00   Shipped  Motorcycles    S10_1678
# ...               ...       ...          ...         ...
# 2818   12/2/2004 0:00   Shipped        Ships    S72_3212
# 2819   1/31/2005 0:00   Shipped        Ships    S72_3212
# 2820    3/1/2005 0:00  Resolved        Ships    S72_3212
# 2821   3/28/2005 0:00   Shipped        Ships    S72_3212
# 2822    5/6/2005 0:00   On Hold        Ships    S72_3212
#
#                   CUSTOMERNAME             PHONE  \
# 0            Land of Toys Inc.        2125557818
# 1           Reims Collectables        26.47.1555
# 2              Lyon Souveniers  +33 1 46 62 7555
# 3            Toys4GrownUps.com        6265557265
# ...

# %%
df[['CUSTOMERNAME', 'STATE']]
# Out:
#                   CUSTOMERNAME STATE
# 0            Land of Toys Inc.    NY
# 1           Reims Collectables   NaN
# 2              Lyon Souveniers   NaN
# 3            Toys4GrownUps.com    CA
# 4     Corporate Gift Ideas Co.    CA
# ...                        ...   ...
# 2818     Euro Shopping Channel   NaN
# 2819   Oulu Toy Supplies, Inc.   NaN
# 2820     Euro Shopping Channel   NaN
# 2821              Alpha Cognac   NaN
# 2822         Gifts4AllAges.com    MA
#
# [2823 rows x 2 columns]

# %%
df[df.columns[2:5]]
# Out:
#       PRICEEACH  ORDERLINENUMBER    SALES
# 0         95.70                2  2871.00
# 1         81.35                5  2765.90
# 2         94.74                2  3884.34
# 3         83.26                6  3746.70
# 4        100.00               14  5205.27
# ...         ...              ...      ...
# 2818     100.00               15  2244.40
# 2819     100.00                1  3978.51
# 2820     100.00                4  5417.57
# 2821      62.24                1  2116.16
# 2822      65.52                9  3079.44
#
# [2823 rows x 3 columns]

# %%
df.loc[10:20, ['CUSTOMERNAME', 'STATE']]
# Out:
#                   CUSTOMERNAME     STATE
# 10  Australian Collectors, Co.  Victoria
# 11             Vitachrome Inc.        NY
# 12     Tekni Collectables Inc.        NJ
# 13             Gift Depot Inc.        CT
# 14           La Rochelle Gifts       NaN
# 15        Marta's Replicas Co.        MA
# 16        Toys of Finland, Co.       NaN
# 17          Baane Mini Imports       NaN
# 18       Diecast Classics Inc.        PA
# 19           Land of Toys Inc.        NY
# 20       Salzburg Collectables       NaN

# %%
df.iloc[10:20, [0,3,2]]
# Out:
#     ORDERNUMBER  ORDERLINENUMBER  PRICEEACH
# 10        10223                1     100.00
# 11        10237                7     100.00
# 12        10251                2     100.00
# 13        10263                2     100.00
# 14        10275                1      92.83
# 15        10285                6     100.00
# 16        10299                9     100.00
# 17        10309                5     100.00
# 18        10318                1      94.74
# 19        10329                1     100.00

# %%
df.query("STATE == 'NY' ")
# Out:
#       ORDERNUMBER  QUANTITYORDERED  PRICEEACH  ORDERLINENUMBER    SALES  \
# 0           10107               30      95.70                2  2871.00
# 11          10237               23     100.00                7  2333.12
# 19          10329               42     100.00                1  4396.14
# 31          10163               21     100.00                1  4860.24
# 54          10107               39      99.91                5  3896.49
# ...           ...              ...        ...              ...      ...
# 2737        10337               36      71.89                7  2588.04
# 2759        10308               39      68.11               15  2656.29
# 2788        10329               44      86.13                8  3789.72
# 2809        10248               23      65.52                9  1506.96
# 2817        10337               42      97.16                5  4080.72
#
#             ORDERDATE     STATUS  QTR_ID  MONTH_ID  YEAR_ID  ...  \
# ...

# %%
df.filter(like='ORDER')
# Out:
#       ORDERNUMBER  QUANTITYORDERED  ORDERLINENUMBER        ORDERDATE
# 0           10107               30                2   2/24/2003 0:00
# 1           10121               34                5    5/7/2003 0:00
# 2           10134               41                2    7/1/2003 0:00
# 3           10145               45                6   8/25/2003 0:00
# 4           10159               49               14  10/10/2003 0:00
# ...           ...              ...              ...              ...
# 2818        10350               20               15   12/2/2004 0:00
# 2819        10373               29                1   1/31/2005 0:00
# 2820        10386               43                4    3/1/2005 0:00
# 2821        10397               34                1   3/28/2005 0:00
# 2822        10414               47                9    5/6/2005 0:00
#
# [2823 rows x 4 columns]

# %%
df.query("STATE == 'NY' and QTR_ID == 1").head()
# Out:
#      ORDERNUMBER  QUANTITYORDERED  PRICEEACH  ORDERLINENUMBER    SALES  \
# 0          10107               30      95.70                2  2871.00
# 54         10107               39      99.91                5  3896.49
# 80         10107               27     100.00                4  6065.55
# 240        10107               21     100.00                1  3036.60
# 475        10102               39     100.00                2  4808.31
#
#           ORDERDATE   STATUS  QTR_ID  MONTH_ID  YEAR_ID  ...  \
# 0    2/24/2003 0:00  Shipped       1         2     2003  ...
# 54   2/24/2003 0:00  Shipped       1         2     2003  ...
# 80   2/24/2003 0:00  Shipped       1         2     2003  ...
# 240  2/24/2003 0:00  Shipped       1         2     2003  ...
# 475  1/10/2003 0:00  Shipped       1         1     2003  ...
#
#                 ADDRESSLINE1  ADDRESSLINE2 CITY STATE POSTALCODE COUNTRY  \
# 0    897 Long Airport Avenue           NaN  NYC    NY      10022     USA
# ...

# %%
df[(df.STATE == 'NY') & (df.QTR_ID == 1)].head()
# Out:
#      ORDERNUMBER  QUANTITYORDERED  PRICEEACH  ORDERLINENUMBER    SALES  \
# 0          10107               30      95.70                2  2871.00
# 54         10107               39      99.91                5  3896.49
# 80         10107               27     100.00                4  6065.55
# 240        10107               21     100.00                1  3036.60
# 475        10102               39     100.00                2  4808.31
#
#           ORDERDATE   STATUS  QTR_ID  MONTH_ID  YEAR_ID  ...  \
# 0    2/24/2003 0:00  Shipped       1         2     2003  ...
# 54   2/24/2003 0:00  Shipped       1         2     2003  ...
# 80   2/24/2003 0:00  Shipped       1         2     2003  ...
# 240  2/24/2003 0:00  Shipped       1         2     2003  ...
# 475  1/10/2003 0:00  Shipped       1         1     2003  ...
#
#                 ADDRESSLINE1  ADDRESSLINE2 CITY STATE POSTALCODE COUNTRY  \
# 0    897 Long Airport Avenue           NaN  NYC    NY      10022     USA
# ...

# %%
df[['STATE', 'PRICEEACH']].groupby('STATE').mean()
# Out:
#                PRICEEACH
# STATE
# BC             84.600000
# CA             82.855769
# CT             85.950328
# Isle of Wight  81.991538
# MA             84.198158
# NH             83.362941
# NJ             84.998095
# NSW            83.194565
# NV             80.441724
# NY             84.633258
# Osaka          82.121000
# PA             85.789333
# Quebec         86.193182
# Queensland     84.736667
# Tokyo          82.745000
# Victoria       83.643462

# %%
df[['COUNTRY', 'STATE']].groupby("COUNTRY").count()
# Out:
#              STATE
# COUNTRY
# Australia      185
# Austria          0
# Belgium          0
# Canada          70
# Denmark          0
# Finland          0
# France           0
# Germany          0
# Ireland          0
# Italy            0
# Japan           52
# Norway           0
# Philippines      0
# Singapore        0
# Spain            0
# Sweden           0
# Switzerland      0
# UK              26
# USA           1004

# %%
df.sort_values(by=['PRICEEACH'], ascending= False)
# Out:
#       ORDERNUMBER  QUANTITYORDERED  PRICEEACH  ORDERLINENUMBER    SALES  \
# 2820        10386               43     100.00                4  5417.57
# 2819        10373               29     100.00                1  3978.51
# 2818        10350               20     100.00               15  2244.40
# 2764        10361               35     100.00               11  4277.35
# 34          10194               42     100.00               11  7290.36
# ...           ...              ...        ...              ...      ...
# 1549        10227               42      29.21                6  1226.82
# 1551        10280               20      28.88               12   577.60
# 1724        10195               32      28.29                7   905.28
# 1543        10162               37      27.22                5  1007.14
# 1563        10420               45      26.88                1  1209.60
#
#             ORDERDATE      STATUS  QTR_ID  MONTH_ID  YEAR_ID  ...  \
# ...
